# %% [markdown]
# ### Последовательный детектор

# %%
import matplotlib.pyplot as plt
import numpy as np
# 50кОм
U_out_50 = np.array([4.3e-6, 11.885e-3, 76e-3, 166.4e-3, 260e-3, 353.2e-3, 447.5e-3, 542e-3, 645e-3, 740e-3, 836e-3, 932e-3, 1, 1.1, 1.22, 1.32, 1.4, 1.5, 1.61, 1.71, 1.8, 1.9, 2, 2.1, 2.2, 2.3, 2.4, 2.5, 2.6, 2.68   ])
U_out_5_posl = np.array([0.000693,
11.878,
68.339,
147.879,
231.525,
316.051,
408.577,
498.185,
590.267,
686.583,
773.002,
867.134,
965.956,
1062,
1162,
1251,
1342,
1448,
1550,
1638,
1737,
1828,
1940,
2014,
2114,
2230,
2315,
2402,
2507,
2619])

U_in = np.linspace(0.1, 3, 30)

plt.figure(figsize=(12, 5))


# График детекторной характеристикиы
plt.plot(U_in, U_out_50, 'bo-', linewidth=1.5, markersize=6, label = '50 кОМ', linestyle='--')
plt.plot(U_in, U_out_5_posl * 1e-3, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Uвых=, В', fontsize=10)
plt.title('Детекторная характеристика', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Коэффициент передачи детектора
Kd_50 = U_out_50 / U_in
Kd_5_1 = U_out_5_posl * 1e-3 / U_in

# График коэффициента передачи детектора
plt.figure(figsize=(10, 5))
plt.plot(U_in, Kd_50, 'bo-', linewidth=1.5, markersize=6, label = '50 кОМ', linestyle='--')
plt.plot(U_in, Kd_5_1, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Kd', fontsize=10)
plt.title('График коэффициента передачи детектора', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()


# Настройка общего отображения
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7580\2617807481.py:42: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "bo-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(U_in, U_out_50, 'bo-', linewidth=1.5, markersize=6, label = '50 кОМ', linestyle='--')
# C:\Users\User\AppData\Local\Temp\ipykernel_7580\2617807481.py:56: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "bo-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(U_in, Kd_50, 'bo-', linewidth=1.5, markersize=6, label = '50 кОМ', linestyle='--')

# %% [markdown]
# ### Детектор с удвоением

# %%
U_out_5 = np.array([0, 7.7e-3, 82e-3, 224e-3, 380.5e-3, 541e-3, 703e-3, 867e-3, 1, 1.2, 1.36, 1.53, 1.7, 1.86, 2, 2.2, 2.36, 2.5, 2.69, 2.86, 3, 3.2, 3.36, 3.5, 3.7, 3.86, 4, 4.2, 4.36, 4.53])


U_in = np.linspace(0.1, 3, 30)

plt.figure(figsize=(12, 5))


# График детекторной характеристикиы
plt.plot(U_in, U_out_5, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')
plt.plot(U_in, U_out_5_posl * 1e-3, 'bo-', linewidth=1.5, markersize=6, label = '5 кОМ (послед)')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Uвых=, В', fontsize=10)
plt.title('Детекторная характеристика', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Коэффициент передачи детектора
Kd_5 = U_out_5 / U_in

# График коэффициента передачи детектора
plt.figure(figsize=(10, 5))
plt.plot(U_in, Kd_5, 'go-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')
plt.plot(U_in, Kd_5_1, 'bo-', linewidth=1.5, markersize=6, label = '5 кОМ (послед)')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Kd', fontsize=10)
plt.title('График коэффициента передачи детектора', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Настройка общего отображения
plt.tight_layout()
plt.show()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7580\1339416413.py:10: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "ro-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(U_in, U_out_5, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')
# C:\Users\User\AppData\Local\Temp\ipykernel_7580\1339416413.py:23: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "go-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(U_in, Kd_5, 'go-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')

# %% [markdown]
# ### Параллельный детектор

# %%
U_out_5 = np.array([0, 30e-3, 94e-3, 181e-3, 273e-3, 368e-3, 464.7e-3, 563e-3, 663e-3, 763e-3, 864e-3, 965e-3, 1.1, 1.17, 1.27, 1.37, 1.47, 1.58, 1.68, 1.78, 1.88, 2, 2.1, 2.2, 2.3, 2.4, 2.5,2.6, 2.7, 2.8 ])

U_in = np.linspace(0.1, 3, 30)

plt.figure(figsize=(12, 5))

# График детекторной характеристикиы
plt.plot(U_in, U_out_5, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Uвых=, В', fontsize=10)
plt.title('Детекторная характеристика', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Коэффициент передачи детектора
Kd_5 = U_out_5 / U_in
# График коэффициента передачи детектора
plt.figure(figsize=(10, 5))
plt.plot(U_in, Kd_5, 'go-', linewidth=1.5, markersize=6, label = '5 кОМ')
plt.xlabel('Uвх, В', fontsize=10)
plt.ylabel('Kd', fontsize=10)
plt.title('График коэффициента передачи детектора', fontsize=12)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Настройка общего отображения
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Зависимость уровня второй гармоники от амплитуды несущей

# %%
garm_2_AD = np.array([94, 91,85,80, 70, 50, 23, 9, 4.7, 2.8])

garm_2_doubleAD = np.array([160, 155, 151, 150])
garm_1_doubleAD = np.array([86, 170, 248, 314])

otnos_2 = garm_2_doubleAD/garm_1_doubleAD
V_peak_1 = np.array([0.05, 0.1, 0.15, 0.2])
V_peak = np.array([0.05, 0.1, 0.15, 0.2, 0.4, 0.6, 0.8, 1, 1.2, 1.4])

plt.figure(figsize=(12, 5))


# График детекторной характеристикиы
plt.plot(V_peak_1, otnos_2, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')
plt.xlabel('Vpeak, В', fontsize=10)
plt.ylabel('2_garm, мВ', fontsize=10)
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_7580\3545575244.py:14: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "ro-" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(V_peak_1, otnos_2, 'ro-', linewidth=1.5, markersize=6, label = '5 кОМ', linestyle='--')
